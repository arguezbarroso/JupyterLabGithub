# %% [markdown]
# ![image.png](attachment:84c886bf-a884-48eb-b4e3-60eb69221ff6.png)
#
# ![image.png](attachment:dbfabcd9-3f22-4f37-8ff5-ee89fe405456.png)
#
# ![image.png](attachment:95372a85-9597-4c7b-9622-06048005ab41.png)
#
# ![image.png](attachment:b4d4130a-b90d-4c12-9750-fdd0e62b3230.png)
#
# ![image.png](attachment:a0deb3c5-4573-4049-bdf4-4fbc51cf370a.png)
#
#
# ![image.png](attachment:c151237d-f43a-4429-aa83-e6b52733dffa.png)
#
# ![image.png](attachment:de272618-77d2-49ea-8163-2d67465ab357.png)
#
# ![image.png](attachment:7395cdfd-9819-431d-b13f-70fb83ceab54.png)
#
# ![image.png](attachment:b198686a-4f8d-4f79-bea9-57c6e89e9cca.png)
#
# ![image.png](attachment:3cc7f6c1-0da5-4c90-81ae-af66c7acfbbe.png)
#
# ```
# PS D:\SW\Programacion\Python\WPy64-3920\notebooks> jupyter server extension list
# Config dir: C:\Users\amroldan\.jupyter
#
# Config dir: D:\SW\Programacion\Python\WPy64-3920\python-3.9.2.amd64\etc\jupyter
#     dask_labextension enabled
#     - Validating dask_labextension...
#       dask_labextension 5.0.1 ok
#     jupyter_lsp enabled
#     - Validating jupyter_lsp...
#       jupyter_lsp 1.1.4 ok
#     jupyter_server_proxy enabled
#     - Validating jupyter_server_proxy...
#       jupyter_server_proxy  ok
#     jupyterlab enabled
#     - Validating jupyterlab...
#       jupyterlab 3.0.9 ok
#     jupyterlab_github enabled
#     - Validating jupyterlab_github...
#       jupyterlab_github 3.0.1 ok
#     jupyterlab_spellchecker enabled
#     - Validating jupyterlab_spellchecker...
#       jupyterlab_spellchecker 0.7.2 ok
#     nbclassic enabled
#     - Validating nbclassic...
#       nbclassic  ok
#     voila.server_extension enabled
#     - Validating voila.server_extension...
#       voila.server_extension  ok
#
# Config dir: C:\ProgramData\jupyter
#
# PS D:\SW\Programacion\Python\WPy64-3920\notebooks> jupyter serverextension list
# config dir: D:\SW\Programacion\Python\WPy64-3920\python-3.9.2.amd64\etc\jupyter
#     dask_labextension enabled
#     - Validating...
#       dask_labextension 5.0.1 ok
#     jupyter_lsp enabled
#     - Validating...
#       jupyter_lsp 1.1.4 ok
#     jupyter_server_proxy enabled
#     - Validating...
#       jupyter_server_proxy  ok
#     jupyterlab enabled
#     - Validating...
#       jupyterlab 3.0.9 ok
#     jupyterlab_spellchecker enabled
#     - Validating...
#       jupyterlab_spellchecker 0.7.2 ok
#     panel enabled
#     - Validating...
#       X is panel importable?
#     voila.server_extension enabled
#     - Validating...
#       voila.server_extension  ok
#     voila enabled
#     - Validating...
#       voila 0.2.7 ok
# PS D:\SW\Programacion\Python\WPy64-3920\notebooks> jupyter server extension enable jupyterlab_github
# Enabling: jupyterlab_github
# - Writing config: D:\SW\Programacion\Python\WPy64-3920\python-3.9.2.amd64\etc\jupyter
#     - Validating jupyterlab_github...
#       jupyterlab_github 3.0.1 ok
#     - Extension successfully enabled.
# PS D:\SW\Programacion\Python\WPy64-3920\notebooks> jupyter --paths
# config:
#     C:\Users\amroldan\.jupyter
#     D:\SW\Programacion\Python\WPy64-3920\python-3.9.2.amd64\etc\jupyter
#     C:\ProgramData\jupyter
# data:
#     D:\SW\Programacion\Python\WPy64-3920\settings
#     D:\SW\Programacion\Python\WPy64-3920\python-3.9.2.amd64\share\jupyter
#     C:\ProgramData\jupyter
# runtime:
#     D:\SW\Programacion\Python\WPy64-3920\settings\runtime
# PS D:\SW\Programacion\Python\WPy64-3920\notebooks> jupyter server --generate-config
# Writing default config to: C:\Users\amroldan\.jupyter\jupyter_server_config.py
# PS D:\SW\Programacion\Python\WPy64-3920\notebooks>
# ```
#
#
# ![image.png](attachment:c7ae24f7-f5ac-4907-9475-c72a53f9458a.png)
#
# Movemos el archivo:  C:\Users\amroldan\.jupyter\jupyter_server_config.py  a:  D:\SW\Programacion\Python\WPy64-3920\settings
#
# o podemos también:
#
# ![image.png](attachment:60f592c6-e70f-43d8-90ca-2b7c5de137da.png)
