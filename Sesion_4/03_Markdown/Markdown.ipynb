# %% [markdown]
# <hr>
#
# # Resumen sobre el uso de códigos Markddown en notebooks de IPython
# ## Recopilado por Andrés Roldán Aranda
#
# <hr>

# %% [markdown]
# ### Ejemplo de reproducción de video en formato M4V
#
# <video controls src="https://github.com/robovm/apple-ios-samples/raw/master/AVTimedAnnotationWriterUsingCustomAnnotationMetadataforMovieWritingandPlayback/AVTimedAnnotationWriter/sample.m4v" width=700, height=300>animation</video>
#
#
# ### Cargar una imagen en BASE 64
#
# ![pycon-logo.jpg](data:image/jpeg;base64,...)

# %%
from IPython.display import IFrame
IFrame("https://www.africau.edu/images/default/sample.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.africau.edu/images/default/sample.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Ejemplo para poner código fuente
#
#
# ```python
# print "Hello World"
# ```
#
# ```javascript
# console.log("Hello World"
#
# ### Ecuaciones
#
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equatio
#
# ### Literales con significado en Markdown
#
# \*literal asterisks\*
#  *literal asterisks*n})
# ```

# %% [markdown]
# ### Numeraciones
#
# Markdown Syntax
#
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### H
# eader 6
# Equivalent HTML Syntax
#
# <h1>Header 1</h1>
# <h2>Header 2</h2>
# <h3>Header 3</h3>
# <h4>Header 4</h4>
# <h5>Header 5</h5>
# <h
#
# ### Tachar
# \~\~Scratch this\~\~
#
# ~~Scratch this~~
# **
# Equivalent HTML Synta**x
#
# <del>Scratch this</d
#
# ### Bloques anidados
# NESTED BLOCK QUOTING
# Markdown Syntax
#
# > some text
# >> and then some more text
# >>> and then some
#
# ### Líneas horizontales
# HORIZONTAL LINE
#
#
# ---
# ___
# ***
#  moreel>6>Header 6</h6>

# %% [markdown]
# ## Imágnes
#
# ![](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
#
# ![][some-id]
#
# [some-id]: https://www.python.org/static/community_logos/python-logo-master-v3-TM.png "Python Log
# o"
# Equivalent HTML Synt
# x
#
# <img src="https://www.python.org/static/community_logos/python-logo-master-v3-TM  png" title="Python Lo me</a>go"/>

# %% [markdown]
# ### STANDARD LINKS
#
# Markdown Syntax
#
# [click me](https://en.wikipedia.org)
#
# Equivalent HTML Syntax
#
# <a href="https://en.wikipedia.org">click me</a>
#
# #### STANDARD LINKS (WITH MOUSE-OVER TITLES)
#
# Markdown Syntax
#
# [click me](https://en.wikipedia.org "Wikiped
# ia")
# Equivalent HTML Syntax
#
# <a href="https://en.wikipedia.org" title=”Wikipedia”>click
#
#
# ### REFERENCE-STYLE LINKS
#
# Markdown Syntax
#
# This is [a reference]
#
# id]
# [id]: https://en.wikipedia.org "Wikip
#
# This is [a reference][]
#
# [a reference]: https://en.wikipedia.org "Wikipedia"
# **
# Equivalent HTML Synta**
# x
#
# This is <a href="https://en.wikipedia.org" title="Wikipedia">a reference</a>edia" me</a>

# %% [markdown]
# ### TASK LISTS
# Markdown Syntax
#
#
# - [x] Some task
# - [ ] Some more
#       task
# Equivalent HTML Syntax
#
# <input type=”checkbox” disabled checked> So
#
# e task
# <input type=”checkbox” disabled> Some more task

# %% [markdown]
# ## Itálicas

# %% [markdown]
# El texto encerrado entre asteriscos `*texto*` se mostrará en itálica: *texto*

# %% [markdown]
# ## Negrita ("Bold" en inglés)

# %% [markdown]
# El texto encerrado entre dobles asteriscos `**texto**` se mostrará en negrita: **texto**

# %% [markdown]
# ## Tachado ("Strike-through" en inglés)

# %% [markdown]
# El texto encerrado entre dobles tidle `~~text~~` is displayed as strike-through: ~~text~~

# %% [markdown]
# ## Fuente con anchura fijada

# %% [markdown]
# El texto encerrado entre un par de comillas simples ` será mostrado usando una fuente de anchura fija:
#
# `texto`

# %% [markdown]
# ## URLs

# %% [markdown]
# URLs podrán ser excritas dentro de un notebook de iPython de la siguiente manera	`[URL text](http://www.example.com)`: [URL text](http://www.example.com)

# %% [markdown]
# ## Nuevo párrafo

# %% [markdown]
# Podremos separar el texto de dos párrafos mediante una línea en blanco.
#
# Así pues este será un nuevo párrafo.

# %% [markdown]
# ## Verbatim o versión textual

# %% [markdown]
# El texto que comience con cuatro espacios será mostrado de manera textual:
#
#     def func(x):
#         return x ** 2

# %% [markdown]
# ## Tablas

# %% [markdown]
# El formato para las tablas será el que sigue:
#
#     | A | B | C |
#     |---|---|---|
#     | 1 | 2 | 3 |
#     | 4 | 5 | 6 |
#
# | A | B | C |
# |---|---|---|
# | 1 | 2 | 3 |
# | 4 | 5 | 6 |
#
# **Equivalente en HTML**
#
# <table>
# <thead>
# <tr><th>Header</th><th>Header</th><th>Header</th></tr>
# </thead>
# <tbody>
# <tr><td>A</td><td>B</td><td>C</td></tr>
# <tr><td>X</td><td>Y</td><td>Z</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ### INLINE HTML
# TEXT COLOR
#
# <span style="color:red">Text</span>
#
# Where color = blue|red|green|pink|yellow
#
# ### TEXT FONT FAMILY
#
# <span style="font-family:Comic Sans MS">This is a text</span>

# %% [markdown]
# ### COLORED NOTE BOXES
#
# Use one of the following <div> tags to display text in a colored box. The color of the box is determined by the alert type that is specified.
#
# Blue boxes (alert-info)
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.</div>
# Yellow boxes (alert-warning)
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed. Typically also used to display warning messag
# es.
# </div>
# Green boxes (alert-success)
#
# <div class="alert alert-block alert-success">
# <b>Success:</b> This alert box indicates a successful or positive
#  action.
# </div>
# Red boxes (alert-danger)
#
# <div class="alert alert-block alert-danger">
# <b>Danger:</b> This alert box indicates a dangerous or potentially neg
# e>ative action.
# </div>

# %% [markdown]
# ### CELL BACKGROUND COLOR
#
# <code style="background:yellow;color:black">Useful for highlighting to grab the attention of the reader towards certain points.</code>

# %% [markdown]
# ### HTML MARK TAG
#
# Highlight parts of a text:
#
# Do not forget to buy <mark>milk</mark> to
# >
# </dl>day.

# %% [markdown]
# ### GEOMETRIC SHAPES
# Use this code with a decimal or hex reference number from here: UTF-8 Geometric shapes
#
# &#reference_numb
#
# &#9635;
#
# Para ver los códigos: https://www.w3schools.com/charsets/ref_utf_geometric.asp
#
#
# <p>I will display &#9658;</p>
# <p>I will display &#x25BA;</p
#
# >er;

# %% [markdown]
# ### DEFINITION LISTS
#
# <dl>
# <dt>First Term</dt>
# <dd>This is the definition of the first term.</dd>
# <dt>Second Term</dt>
# <dd>This is one definition of the second term. </dd>
# <dd>This is another definition of the second term.</dd>
# </dl>

# %% [markdown]
# ## Línea horizontal

# %% [markdown]
# Una línea con tres guiones `---` será mostrada como una línea horizontal:
#
# ---

# %% [markdown]
# ## Cabeceras y secciones a distintos niveles

# %% [markdown]
# Las lineas que comiencen con un signo de almohadilla `#` tendrá un nivel 1, `##` será una cabecera de nivel 2, `###` de nivel 3, etc.
#
# # Cabecera de nivel 1
# ## Cabecera de nivel 2
# ### Cabecera de nivel 3

# %% [markdown]
# ## Bloques textuales ("Block quotes" en inglés)

# %% [markdown]
# Las líneas que comiencen con el símbolo `>` serán mostradas como un bloque de cita textual:
#
# > El texto indentado aquí será sangrado
# > respecto al cuerpo principal del texto normal.

# %% [markdown]
# ## Listas sin números ordinales

# %% [markdown]
# Listas sin números ordinales pueden ser creadas comenzando lineas con el símbolo `*`
#
# * Item uno
# * Item dos
# * Item tres

# %% [markdown]
# ## Listas con números ordinales

# %% [markdown]
# Listas con números ordinales son creadas simplemente enumerando las correspondientes líneas con números seguidos de un punto: 1. ..., 2. ..., etc.
# 1. Item uno
# 2. Item dos
# 3. Item tres

# %% [markdown]
# ## Imágenes

# %% [markdown]
# Se puede incluir imágenes usando `![Texto alternativo](fichero-imagen.png)` o `![Texto alternativo](http://www.example.com/image.png)`:
#
# ![Texto alternativo](image-file.png)
#
# ![Texto alternativo](http://www.example.com/image.png)

# %% [markdown]
# ## Introducción de código LaTeX

# %% [markdown]
# Ecuaciones LaTeX en línea pueden ser incluidas usando `$\LaTeX$`: $\LaTeX$
#
# Mientras que ecuaciones LaTeX resaltadas (centradas, y en una nueva línea): `$$\LaTeX$$`
#
# $$\LaTeX$$
#
# También es posible usar diferentes entornos LaTeX, como por ejemplo equation, eqnarray, align:
#
# `\begin{equation} x = 1 \end{equation}`
#
# \begin{equation} x = 1 \end{equation}
#
# `\begin{eqnarray} x = 2 \end{eqnarray}`
#
# \begin{eqnarray} x = 2 \end{eqnarray}
#
# `\begin{align} x = 3 \end{align}`
#
# \begin{align} x = 3 \end{align}

# %% [markdown]
# ## Versión de Python y de los distintos paquetes empleados en este notebook

# %%
# !pip install version-information
# Out:
# ...
#   Using cached version_information-1.0.4-py3-none-any.whl
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip show version-information
# Out:
# Name: version-information
# Version: 1.0.4
# Summary: Version information:
# Home-page: https://github.com/jrjohansson/version_information
# Author: J. Robert Johansson
# Author-email: jrjohansson@gmail.com
# License: BSD
# Location: d:\sw\programacion\python\wpy64-3920\python-3.9.2.amd64\lib\site-packages
# Requires:
# Required-by:

# %%
# %load_ext version_information
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information

# %%
# %reload_ext version_information

# %%
# %version_information
# Out:
# Software versions
# Python 3.9.2 64bit [MSC v.1928 64 bit (AMD64)]
# IPython 7.21.0
# OS Windows 10 10.0.19041 SP0
# Tue Jun 20 22:07:29 2023 Hora de verano romance

# %%
from IPython.display import SVG
SVG(url='https://upload.wikimedia.org/wikipedia/commons/6/6e/LAN_WAN_scheme.svg')

# %%
from IPython.display import HTML, Image, Latex, Math, Markdown, SVG
img = Image("https://nocomplexity.com/wp-content/uploads/2020/06/computer-1210791_640.jpg")
img

# %%
from IPython.display import JSON
JSON({ "name": "Tester McTester",
      "age": 20, "location": 
      "The North Pole",
      "job": { "title": "Senior Engineer", "employer": { "name": "Acme Inc.", "id": 1 } } })

# %%
from IPython.display import display, Markdown
display(Markdown('./Files/ExampleMarkdown.md'))
# Out:
# This document contains example output to show RDoc styling.  This file was
# created from a Markdown file.
#
# For the following styles, see ExampleRDoc.rdoc for style examples:
#
# * Headings
# * Paragraphs
# * Code blocks (verbatim sections)
# * Definition lists
# * Ordered lists
# * Unordered lists
#
# These items all use the same styles as RDoc format files.
#
# ## Footnotes
#
# Footnotes are rendered at the bottom of the documentation section[^1].  For
# pages this will be at the bottom of the page.  For method documentation this
# will be at the end of the current method.
#
# [^1]: Here is the footnote content.  As you can see it is at the bottom of the
# page.
#
# ## Blockquotes
#
# Here is how a blockquote looks.
#
# > We finished our first sensor sweep of the neutral zone. Now, how the hell do
# > we defeat an enemy that knows us better than we know ourselves? and attack
# > the Romulans.
# >
# > > Sorry, Data. I guess it's better to be lucky than good. The unexpected is
# ...

# %%
from IPython.display import IFrame
IFrame("https://bm-support.org", width="80%", height="80%")
# Out:
#         <iframe
#             width="80%"
#             height="80%"
#             src="https://bm-support.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
output='<h2> This is a html header2 </h2> <p>And this is html text</p>'
from IPython.display import display, HTML
from IPython.display import YouTubeVideo

YouTubeVideo('<videoID, e.g.A5YyoCKxEOU like example below >' , width=700, height=300)display(HTML(output))
# Out:
#   File "<ipython-input-1-a936e79aabd5>", line 5
#     YouTubeVideo('<videoID, e.g.A5YyoCKxEOU like example below >' , width=700, height=300)display(HTML(output))
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
#from IPython.display import YouTubeVideo
#YouTubeVideo('<videoID, e.g.A5YyoCKxEOU like example below >' , width=700, height=300)


from IPython.display import YouTubeVideo

YouTubeVideo('A5YyoCKxEOU', width=700, height=300)

# %% [markdown]
# # Shortcuts
#
# **Command Mode (press Esc to enable)**
# ```
# F : find and replace
# Ctrl-Shift-F : open the command palette
# Ctrl-Shift-P : open the command palette
# Enter : enter edit mode
# P : open the command palette
# Shift-Enter : run cell, select below
# Ctrl-Enter : run selected cells
# Alt-Enter : run cell and insert below
# Y : change cell to code
# M : change cell to markdown
# R : change cell to raw
# 1 : change cell to heading 1
# 2 : change cell to heading 2
# 3 : change cell to heading 3
# 4 : change cell to heading 4
# 5 : change cell to heading 5
# 6 : change cell to heading 6
# K : select cell above
# Up : select cell above
# Down : select cell below
# J : select cell below
# Shift-K : extend selected cells above
# Shift-Up : extend selected cells above
# Shift-Down : extend selected cells below
# Shift-J : extend selected cells below
# Ctrl-A : select all cells
# A : insert cell above
# B : insert cell below
# X : cut selected cells
# C : copy selected cells
# Shift-V : paste cells above
# V : paste cells below
# Z : undo cell deletion
# D,D : delete selected cells
# Shift-M : merge selected cells, or current cell with cell below if only one cell is selected
# Ctrl-S : Save and Checkpoint
# S : Save and Checkpoint
# L : toggle line numbers
# O : toggle output of selected cells
# Shift-O : toggle output scrolling of selected cells
# H : show keyboard shortcuts
# I,I : interrupt the kernel
# 0,0 : restart the kernel (with dialog)
# Ctrl-V : Dialog for paste from system clipboard
# Esc : close the pager
# Q : close the pager
# Shift-L : toggles line numbers in all cells, and persist the setting
# Shift-Space : scroll notebook up
# Space : scroll notebook down
# ```
#
#
# **Edit Mode (press Enter to enable)**
# ```
# Tab : code completion or indent
# Shift-Tab : tooltip
# Ctrl-] : indent
# Ctrl-[ : dedent
# Ctrl-A : select all
# Ctrl-Z : undo
# Ctrl-/ : comment
# Ctrl-D : delete whole line
# Ctrl-U : undo selection
# Insert : toggle overwrite flag
# Ctrl-Home : go to cell start
# Ctrl-Up : go to cell start
# Ctrl-End : go to cell end
# Ctrl-Down : go to cell end
# Ctrl-Left : go one word left
# Ctrl-Right : go one word right
# Ctrl-Backspace : delete word before
# Ctrl-Delete : delete word after
# Ctrl-Y : redo
# Alt-U : redo selection
# Ctrl-M : enter command mode
# Ctrl-Shift-F : open the command palette
# Ctrl-Shift-P : open the command palette
# Esc : enter command mode
# Shift-Enter : run cell, select below
# Ctrl-Enter : run selected cells
# Alt-Enter : run cell and insert below
# Ctrl-Shift-Minus : split cell at cursor(s)
# Ctrl-S : Save and Checkpoint
# Down : move cursor down
# Up : move cursor up
# ```

# %%
# %quickref
# Out:
# IPython -- An enhanced Interactive Python - Quick Reference Card
# ...
#
# obj?, obj??      : Get help, or more help for object (also works as
#                    ?obj, ??obj).
# ?foo.*abc*       : List names in 'foo' containing 'abc' in them.
# %magic           : Information about IPython's 'magic' % functions.
#
# Magic functions are prefixed by % or %%, and typically take their arguments
# without parentheses, quotes or even commas for convenience.  Line magics take a
# single % and cell magics are prefixed with two %%.
#
# Example magic function calls:
#
# %alias d ls -F   : 'd' is now an alias for 'ls -F'
# alias d ls -F    : Works if 'alias' not a python name
# alist = %alias   : Get list of aliases to 'alist'
# cd /usr/share    : Obvious. cd -<tab> to choose from visited dirs.
# %cd??            : See help AND source for magic %cd
# %timeit x=10     : time the 'x=10' statement with high precision.
# %%timeit x=2**100
# ...

# %%
x= [i for i in range(7)]
x
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
# ?print
# Out:
# Docstring:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
??pprint
# Out:
# Source:
#     @line_magic
#     def pprint(self, parameter_s=''):
#         """Toggle pretty printing on/off."""
#         ptformatter = self.shell.display_formatter.formatters['text/plain']
#         ptformatter.pprint = bool(1 - ptformatter.pprint)
#         print('Pretty printing has been turned',
#               ['OFF','ON'][ptformatter.pprint])
# File:   d:\sw\programacion\python\wpy64-3920\python-3.9.2.amd64\lib\site-packages\ipython\core\magics\basic.py

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %version_information  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %%
# !jupyter-lab -h
# Out:
# JupyterLab - An extensible computational environment for Jupyter.
#
# This launches a Tornado based HTML Server that serves up an HTML5/Javascript
# JupyterLab client.
#
# JupyterLab has three different modes of running:
#
# * Core mode (`--core-mode`): in this mode JupyterLab will run using the JavaScript
#   assets contained in the installed `jupyterlab` Python package. In core mode, no
#   extensions are enabled. This is the default in a stable JupyterLab release if you
#   have no extensions installed.
# * Dev mode (`--dev-mode`): uses the unpublished local JavaScript packages in the
#   `dev_mode` folder.  In this case JupyterLab will show a red stripe at the top of
#   the page.  It can only be used if JupyterLab is installed as `pip install -e .`.
# * App mode: JupyterLab allows multiple JupyterLab "applications" to be
#   created by the user with different combinations of extensions. The `--app-dir` can
# ...

# %%
# !jupyter-lab --help-all
# Out:
# JupyterLab - An extensible computational environment for Jupyter.
#
# This launches a Tornado based HTML Server that serves up an HTML5/Javascript
# JupyterLab client.
#
# JupyterLab has three different modes of running:
#
# * Core mode (`--core-mode`): in this mode JupyterLab will run using the JavaScript
#   assets contained in the installed `jupyterlab` Python package. In core mode, no
#   extensions are enabled. This is the default in a stable JupyterLab release if you
#   have no extensions installed.
# * Dev mode (`--dev-mode`): uses the unpublished local JavaScript packages in the
#   `dev_mode` folder.  In this case JupyterLab will show a red stripe at the top of
#   the page.  It can only be used if JupyterLab is installed as `pip install -e .`.
# * App mode: JupyterLab allows multiple JupyterLab "applications" to be
#   created by the user with different combinations of extensions. The `--app-dir` can
# ...

# %%
message = "hello from Python"

# !echo {message}
# Out:
# hello from Python
