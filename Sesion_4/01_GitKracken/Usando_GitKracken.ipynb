# %% [markdown]
# # Usando GITHUB con GitKraken
#
# | ![image.png](attachment:a9db1f33-8f74-40a8-9184-b55d772eafb0.png) |
# | :-: |
# | ![image.png](attachment:7275bc44-72e0-4eec-9bb7-0d2a43ff747a.png) |
# |**Figura 1**. Doble Click al icono del GitKracken     |
#
#
# |  ![image.png](attachment:0c71d0cf-d3cf-4def-845e-2f7b77ae7e97.png) |
# | :-: |
# |**Figura 2**. Nos identificamos con nuestra cuenta de GITHUB de profesor  |
#
# | ![image.png](attachment:ec9487c6-1f4d-425f-b77b-d280c5184ba2.png)  |
# | :-: |
# |**Figura 3**. Algunas veces hay actualizaciones que debemos instalar. |
#
# | ![image.png](attachment:6107bb4e-466d-48f0-9c64-1803fbfe6782.png) |
# | :-: |
# |**Figura 4**. Notas de la nueva versión. |
#
#
#  | ![image.png](attachment:7593762d-dd84-4e58-a0be-e07c76615dbe.png) |
# | :-: |
# |**Figura 5**. Creamos un **Workspace** para reunir nuestros repositorios. |
#
# ![image.png](attachment:41091b3e-4ed9-4265-8989-759b6da280c4.png)|
# | :-: |
# |**Figura 6**. Creamos un **Workspace** con nuestro repositorio. |
#
# | ![image.png](attachment:59ca72de-3f29-485b-8a5e-d8131748fc23.png)|
# | :-: |
# |**Figura 7**. Vemos nuestro **Workspace** en la vista del ***Focus View***. |
#
#
# | ![image.png](attachment:d16d8ea2-f596-4b99-9bbe-c0858a4999b8.png)|
# | :-: |
# |**Figura 8**. Vemos nuestro **Workspace** en la vista del ***Repositorio***. |
#
# Ahora vamos a conectar el Workspace con nuestro repositorio en la Carpeta NoteBook del JupyterLab de nuestro ordenador para que se suba todo al GitHUB.
#
# | ![image.png](attachment:7431c0a7-318e-42bb-a559-b2fefa00fb6a.png)|
# | :-: |
# |**Figura 9**. Hacemos Click en ***Clone Repository***. |
#
# | ![image.png](attachment:31401d99-ef4c-493b-be22-76f021f2401a.png) |
# | :-: |
# |**Figura 9**. Buscamos nuestra carpeta de los ***Notebook*** en nuestro PC. |
#
# | ![image.png](attachment:55be5aa7-ad89-4247-9c6a-a2f71a70160d.png)|
# | :-: |
# |**Figura 10**. Seleccionamos nuestra carpeta de los ***Notebook*** en nuestro PC. |
#
# | ![image.png](attachment:f59825f4-8d85-491d-b918-9f03a4569bfe.png) |
# | :-: |
# |**Figura 11**. Aparece nuestro repositorio, su propietario y la rama que será normalmente  ***main***. |
#
# | ![image.png](attachment:c3374864-7e61-4bfa-98af-5571d74e1500.png) |
# | :-: |
# |**Figura 12**. Buscamos nuestra carpeta donde vamos a tener todo ordenado y replicado en el   **Github**. |
#
# | ![image.png](attachment:550c7a3a-2300-4886-bf1d-511e3b0f141b.png)  |
# | :-: |
# |**Figura 13**. Editamos el README.MD y usando el mismo lenguaje MARKDOWN actualizamos el contenido. |
#
# | ![image.png](attachment:26ac7d4a-c628-4b40-ab1d-ccebbb58bf35.png)  |
# | :-: |
# |**Figura 14**. Actualizamos el contenido README.MD |
#
# | ![image.png](attachment:096f864b-1707-41e4-9e8f-655193c87991.png) |
# | :-: |
# |**Figura 15**. Guardamos el fichero con la actualización del contenido README.MD |
#
# | ![image.png](attachment:9a294be1-ade1-459d-94b0-cf1ef156bf74.png)  |
# | :-: |
# |**Figura 16**. Ya vemos en GitKraken que se ha producido una modificación en un fichero. |
#
# | ![image.png](attachment:b67e0eb0-a620-4230-b2b9-7eb5f3686c68.png) |
# | :-: |
# |**Figura 17**. Movemos la carpeta del **Curso de Python para Control Remoto** a la carpeta controlada por **Gitkraken** y que replicaremos a **Github**. |
#
# Si en **GitKraken** cambiamos de pestaña y volvemos se ven los 362 cambios que hemos realizado.
#
#  | ![image.png](attachment:9ec04f54-4e7d-477d-bb0a-d71f8661dd7d.png) |
# | :-: |
# |**Figura 18**. Movemos la carpeta del **Curso de Python para Control Remoto** a la carpeta controlada por **Gitkraken** y que replicaremos a **Github**. |
#
# Si ponchamos en el enlace disponible sobre el número de cambios nos sale esta ventana en el **GitKraken**.
#
# | ![image.png](attachment:e7d8e14f-3b2b-4dc6-8b01-46f81ed6946c.png)|
# | :-: |
# |**Figura 19**. Ficheros pendientes para subir con **Gitkraken** a nuestro **Github**. |
#
# |![image.png](attachment:07d3da0c-d76d-43fd-9bc0-711789033bd8.png) |
# | :-: |
# |**Figura 20**. En el **Gitkraken** le damos a que organice los cambios . |
#
# | ![image.png](attachment:f39bfdd6-6ae7-49ff-9aab-bf67d416607a.png)  |
# | :-: |
# |**Figura 21**. Tras realizar la organización **Gitkraken** nos muestra los *Staged Files* y nos permite meter en la ventana de *Commit Message* el texto asociado a esta actualización de ficneros . |
#
# | ![image.png](attachment:6f88ad20-4183-4216-944c-eca70c20fd4c.png)  |
# | :-: |
# |**Figura 21**. Le damos instrucciones a **Gitkraken** para que prepare la subida los ficheros al GITHUB. |
#
# | ![image.png](attachment:937ba4a8-6579-45ab-a38c-6a9044e6aeb8.png) |
# | :-: |
# |**Figura 22**.  **Gitkraken** ha realizado los cambios y detecta que el Notebook sigue siendo modificado. |
#
# | ![image.png](attachment:610940d9-4c41-431a-b491-7fc98fb27e2c.png)  |
# | :-: |
# |**Figura 23**. Le damos a **PUSH** para que  **Gitkraken** suba los ficheros a **Github**.
#
# Si  nos vamos a GITHUB deberíamos ver nuestros ficheros allí subidos.
#
# | ![image.png](attachment:de1fe98a-16f5-4d2e-9879-c66cca84387b.png) |
# | :-: |
# |**Figura 23**. Vemos el estado del repositorio en **GitHUB**. |
