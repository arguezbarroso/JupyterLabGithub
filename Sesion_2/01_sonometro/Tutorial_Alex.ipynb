# %% [markdown]
# # Procedimiento de instalación del software del fabricante
#
# |![image.png](attachment:b4169fa2-6b99-4b01-9c17-fa69ca68fa4a.png)|
# | :-: |
# | **Figura 1**: Icono para instalar el controlador del sonómetro |
#
# |![image.png](attachment:352d50cb-597f-4708-8028-8b026ca22051.png)|
# | :-: |
# | **Figura 2**: Pantalla que aparece cuando se va a instalar el programa |
#
# Entramos en el administrados de dispositivos:
# ![image.png](attachment:2bc3a4c7-dbaf-4643-b68f-38d997d161fc.png)
#
# (Echarle un ojo a ShareX)
#
# Buscamos los puertos COM:
# ![image.png](attachment:2009f109-16f2-43d0-a037-eead240c1212.png)
#
# Abrimos el programa HandHeld:
# ![image.png](attachment:ac9748ca-67bb-498d-bfc4-cd74a6a549dd.png)
#
# Ponemos la velocidad a 2400Baudios:
# ![image.png](attachment:aff851e2-937f-4159-af98-998dc24beca8.png)
#
# Calibramos el sonómetro a 114dB a 1kHz poniéndolo en la punta del micrófono. Sale 115.2dB
#
# Exportamos el documento de jupiter a HTML embebido.
