# %% [markdown]
# |![image.png](attachment:598c07af-c40c-4e37-bc1d-817becb76192.png)|
# | :-: |
# |**Figura 1**. Ejemplo de datos de un punto de red    |
#
# |![image.png](attachment:bf3de904-e6eb-45ee-b201-772c3b78ef4d.png)|
# | :-: |
# |**Figura 2**. Ejemplo de datos de un punto de red    |
#
# |![image.png](attachment:a0aea46b-c82d-4d2c-aa15-40408956611a.png)|
# | :-: |
# |**Figura 3**. Ejemplo de datos de un punto de red    |
#
# |![image.png](attachment:8200e46b-8040-4290-a464-66a1ec0d17d9.png)|
# | :-: |
# |**Figura 4**. Ejemplo de datos de un punto de red    |
#
# | ![image.png](attachment:29db0b51-4cd8-455e-a562-642873087530.png) |
# | :-: |
# |**Figura 5**. Ejemplo de datos de un punto de red    |
#
# # Procedimiento para obtener la titularidad de un punto de RED
# ## Fecha: Martes, 6 de junio de 2023
# #### Autor: Andrés Roldán Aranda
#
# Para obtener la titularidad hay que rellenar un documento que hay disponible en la web del CSIRC.
# Si no sabemos quién es el titular, se envía un correo al Departamento o Grupo de Investigación y se le pide a los compañeros que miren si son los titulares del punto de red que hay en la pared que tiene *PB-D71*, **PB-D71**, ***PB-D71***
#
#
# # TABLE
# A table can be constructed using | (pipe symbol) and — (dash) to mark columns and rows.
#
# ### Markdown Syntax
#
# |Header|Header|Header|
# |------|------|------|
# |A     |B     |C     |
# |X     |Y     |Z     |
#
#
# ***Note: It is not important to add spaces after each text, roughly aligning with the columns will do just fine. Also, the number of dashes is irrelevant and is just cosmetical.***
#
# The text in each header and cell of a table will by default justify to the right.
#
# For manually changing the justification, you can use:
#
#     Use :-: for centered
#
#     Use — for right centered
#
#     Use :- for left centered

# %% [markdown]
# |  ![image.png](attachment:0d697cb1-e48c-46eb-b2c1-51119b60364c.png) |
# | :-: |
# |**Figura 1**. Ejemplo de figura bien bonita     |
#
#
# | ![image.png](attachment:3adb84ee-f505-418f-b4f9-8442bf9384d6.png) |
# | :-: |
# |**Figura 2**. Ejemplo de router neutros para los despachos y laboratorios    |
#
# Los routers modernos suelen tener muchas antenas para mejorar la diversisdad espacial y que la cobertura efectiva sea más homogénea.
#
# | ![image.png](attachment:341261c1-6d21-48a8-ae73-1b1b61de30e6.png) |
# | :-: |
# |**Figura 3**. Ejemplo de router neutro con muchas antenas    |
#
# | ![image.png](attachment:4769b0a6-c92a-4063-a8df-b501ca058d1c.png)  |
# | :-: |
# |**Figura 4**. Parte trasera del Router. Importante identificar la red WAN que controla el CSIRC y la LAN que la administramos nosotros.    |
#
# | ![image.png](attachment:ff8e07ca-db70-4218-97d9-a6838bb9ef1b.png)  |
# | :-: |
# |**Figura 5**. Típico conector RJ45 para conexión Ethernet que usaremos en el Router    |
#
#
#
# | ![Alt text](https://upload.wikimedia.org/wikipedia/commons/6/6e/LAN_WAN_scheme.svg)|
# | :-: |
# |**Figura 5B**. Arquitectura de RED LAN/WAN.   |
#
#
#
# | ![image.png](attachment:8b3e8af2-2213-421f-b083-fc9c66d9c11b.png)  |
# | :-: |
# |**Figura 6**. ¿Qué hacemos para conectar más ordenadores/equipos si con los puertos de la LAN nos faltan.   |
#
#
# | ![image.png](attachment:51b56f74-5866-44c8-a1b6-ba978363db3b.png) |
# | :-: |
# |**Figura 7**. Si tenemos muchas conexiones recomiendo usar un armario de comunicaciones o RACK para tener ordenado el cableado.   |
#
#
#
#
# | ![image.png](attachment:958a3555-dad8-40f1-92eb-3744f8dcdca5.png)  |
# | :-: |
# |**Figura 8**. Herramientas necesarias para conectorizar.   |
#
# | ![image.png](attachment:5166b481-66a5-4c6a-905e-2a0253adaae0.png)|
# | :-: |
# |**Figura 8**. Procedimiento para fabricar el cableado.   |

# %%
# from IPython.display import SVG
# SVG(url='https://upload.wikimedia.org/wikipedia/commons/6/6e/LAN_WAN_scheme.svg')
