# %% [markdown]
# ## This is the data configuration for the router:

# %%
from IPython.display import IFrame
IFrame("./PDF/Router TL-WR84N.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="./PDF/Router TL-WR84N.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Reset the configuration of the router:

# %% [markdown]
# ![image.png](attachment:b818b460-a856-407c-8d20-fae9cbccebcb.png)

# %% [markdown]
# The reset button is situated in the back of the device (pag. 5 from the attached PDF):

# %% [markdown]
# ![image.png](attachment:feb47742-e239-4703-b446-f5fe800d0bcb.png)

# %% [markdown]
# Nota: para ver el pdf en la ventana debe tenerse activado el plugin de adobe.
# Nota 2: Se recomienda tener un post.it en la parte trasera del router para tener la información disponible.

# %% [markdown]
# # Los datos de la conexión de red son:

# %% [raw]
# Sufijo DNS específico para la conexión. . :
#    Descripción . . . . . . . . . . . . . . . : Realtek PCIe GbE Family Controller
#    Dirección física. . . . . . . . . . . . . : 10-E7-C6-F3-4C-DD
#    DHCP habilitado . . . . . . . . . . . . . : no
#    Configuración automática habilitada . . . : sí
#    Vínculo: dirección IPv6 local. . . : fe80::fce5:5514:dc4c:e92f%2(Preferido)
#    Dirección IPv4. . . . . . . . . . . . . . : 172.25.102.81(Preferido)
#    Máscara de subred . . . . . . . . . . . . : 255.255.254.0
#    Puerta de enlace predeterminada . . . . . : 172.25.102.222
#    IAID DHCPv6 . . . . . . . . . . . . . . . : 34662342
#    DUID de cliente DHCPv6. . . . . . . . . . : 00-01-00-01-25-6D-53-27-10-E7-C6-F3-4C-DD
#    Servidores DNS. . . . . . . . . . . . . . : 150.214.204.10
#    NetBIOS sobre TCP/IP. . . . . . . . . . . : habilitado

# %% [raw]
# Nota: Siempre que se pueda es preferible funcionar con cable en lugar de por wifi. Nuestros routers son routers neutros. Tienen un puerto separado. Por el puerto separado entreará la WAN, que será el internet de la universidad.

# %% [markdown]
# # Accedamos al menú de configuración de internet desde windows 11

# %% [markdown]
# ![image.png](attachment:76aafef1-3b33-4725-b180-a8c50a2eec8e.png)

# %% [markdown]
# ![image.png](attachment:4b5f9f13-8b3f-4f99-8858-ca01997c1bdd.png)

# %% [markdown]
# ![image.png](attachment:49157a14-04bf-4b6f-a62a-cbb18340c907.png)

# %% [raw]
# Necesitamos asegurarnos de que tengamos la configuración de nuestra tarjeta de red en DHCP y no en IP fija.

# %% [markdown]
# ![image.png](attachment:c9e71a37-9957-41cf-b478-4e3215a44de0.png)

# %% [markdown]
# Nos conectamos al router mediante: http://192.168.0.1 o alternativamente a la direcciÓn:  http://tplinkwifi.net

# %% [markdown]
# datos de acceso: "admin123" y contraseña: "admin123"

# %% [raw]
# Ahora hay que configurar la dirección IP y la toma de RED. Dentro de WAN ponemos los siguientes valores:

# %% [markdown]
# ![image.png](attachment:864c80a4-686b-483b-9354-003c04377098.png)

# %% [markdown]
# Hay que poner la MAC que pide, que es:

# %% [markdown]
# ![image.png](attachment:ef2baa96-860a-43b8-8b7d-3129ef946c4f.png)

# %% [raw]
# Los parámetros de la LAN podemos ponerlos como queramos puesto que corresponden a nuestros parámetros del laboratorio o del despacho. La dirección IP de la LAN en nuestro caso sería 192.168.0.1 y la máscara de subred 255.255.255.0

# %% [markdown]
# Habilitar servidor DHCP en el router:

# %% [markdown]
# Los valores del router quedan como:

# %% [markdown]
# ![image.png](attachment:644c9c05-30cb-4475-835d-61e2372963c1.png)

# %% [markdown]
# Nota: Google keep puede servir para guardar las contraseñas de los routers

# %% [raw]
# La asignación automática de IP del DHCP es que las IPs internas pueden ir cambiando. Por tanto, nuestro PC de casa no sabrá a qué IP del laboratorio debería conectarse.

# %% [markdown]
# El tiempo del ping es importante para evitar retardos:

# %% [markdown]
# ![image.png](attachment:88dfd70f-6dc6-408b-8cd2-8ab74f178986.png)

# %%
# !ping 172.25.102.81
# Out:
# Haciendo ping a 172.25.102.81 con 32 bytes de datos:
# Respuesta desde 192.168.1.1: Red de destino inaccesible.
# Respuesta desde 192.168.1.1: Red de destino inaccesible.
# Respuesta desde 192.168.1.1: Red de destino inaccesible.
# Respuesta desde 192.168.1.1: Red de destino inaccesible.
#
# Estad¡sticas de ping para 172.25.102.81:
#     Paquetes: enviados = 4, recibidos = 4, perdidos = 0
#     (0% perdidos),

# %%
# !ping 192.168.1.135 #Óscar's PC
# Out:
# Haciendo ping a 192.168.1.135 con 32 bytes de datos:
# Respuesta desde 192.168.1.135: bytes=32 tiempo=1ms TTL=128
# Respuesta desde 192.168.1.135: bytes=32 tiempo=2ms TTL=128
# Respuesta desde 192.168.1.135: bytes=32 tiempo=1ms TTL=128
# Respuesta desde 192.168.1.135: bytes=32 tiempo=1ms TTL=128
#
# Estad¡sticas de ping para 192.168.1.135:
#     Paquetes: enviados = 4, recibidos = 4, perdidos = 0
#     (0% perdidos),
# Tiempos aproximados de ida y vuelta en milisegundos:
#     M¡nimo = 1ms, M ximo = 2ms, Media = 1ms

# %% [markdown]
# Se relaciona cada MAC de los equipos conectados con una IP aignada fija.

# %% [markdown]
# Personas responsables de redes del CSIRC.
# Antonio (responsable), Enrique Vargas, Joaquín

# %% [markdown]
# Si el dispositivo es serie se puede meter rs232 con un conversor rs232 a ethernet.

# %% [markdown]
# # Habilitar escritorio remoto

# %% [markdown]
# Los usuarios deben tener contraseña para que el escritorio remoto funcione

# %% [markdown]
# ![image.png](attachment:27823d5a-7e13-4fcc-b412-b181cdf8d6c0.png)

# %% [markdown]
# En la versión home sólo podemos utilizar el cliente del escritorio remoto. Esto funciona sólo cuando nos conectamos por VPN.

# %% [markdown]
# 3389 es el puerto por defecto para el escritorio remoto. 80 es para internet. En el router hay que decir que cuando llegue algo preguntando por alguno de esos puertos hay que redirigir ese servicio a una ip de la LAN.
