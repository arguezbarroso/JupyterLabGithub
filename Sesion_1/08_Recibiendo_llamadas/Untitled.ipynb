# %% [markdown]
# # Procedimiento de Uso del MicroSIP
# ## 2/6/2023
# ### Alejandro Rodríguez

# %% [markdown]
# Para capturar la imagen de manera rápida en Windows 10 pulso Mayusc + Win + S:
#
# ![image.png](attachment:94f17146-2def-4c29-b7e7-fb34b84853bc.png)
