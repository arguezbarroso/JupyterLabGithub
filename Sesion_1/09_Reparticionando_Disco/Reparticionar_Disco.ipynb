# %% [markdown]
# # Manual para administración de Windows de Windows 11
#
# En la barra de búsqueda pongo "Mi PC" y le doy con el botón derecho y le doy a "Administrar"
#
# ![image.png](attachment:01319641-ef8d-4864-80a5-ba204bd7589f.png)
#
# Aparecerá la siguiente ventana:
#
# ![image.png](attachment:948dca8e-3b87-41d3-8d35-f964bd8b4360.png)
#
# Seleccionamos administrador de discos:
#
# ![image.png](attachment:7497a70c-ed7d-4eb0-a9ad-30a495409684.png)
#
#
# Reducimos el tamaño del disco:
#
# ![image.png](attachment:242c0133-d0e8-4b00-8e0b-5b3fb52b9d10.png)
